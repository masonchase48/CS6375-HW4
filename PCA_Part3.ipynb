# %%
import imageio
import requests
from io import BytesIO
import numpy as np

url = 'http://www.utdallas.edu/~axn112530/cs6375/unsupervised/images/image1.jpg'
response = requests.get(url)
image1 = imageio.imread(BytesIO(response.content))

url = 'http://www.utdallas.edu/~axn112530/cs6375/unsupervised/images/image2.jpg'
response = requests.get(url)
image2 = imageio.imread(BytesIO(response.content))

url = 'http://www.utdallas.edu/~axn112530/cs6375/unsupervised/images/image3.jpg'
response = requests.get(url)
image3 = imageio.imread(BytesIO(response.content))

# %%
import matplotlib.pyplot as plt

plt.imshow(image1 / 255.0)
plt.draw()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.imshow(image2 / 255.0)
plt.draw()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.imshow(image3 / 255.0)
plt.draw()
plt.show()

# %%
from sklearn.decomposition import PCA

def compress_pca(image, pct_var = 0.95):
    width, height, depth = image.shape
    reshaped_image = np.reshape(image, (-1, 3))
    reshaped_image = np.reshape(reshaped_image, (2000, int(reshaped_image.shape[1] * reshaped_image.shape[0] / 2000)))
    pca = PCA(pct_var)
    lower_dimensional_data = pca.fit_transform(reshaped_image)
    approximation = pca.inverse_transform(lower_dimensional_data)
    appx = np.reshape(approximation, (width, height, depth))
    return appx

# %%
apx11 = compress_pca(image1, pct_var = 0.99)
apx12 = compress_pca(image1, pct_var = 0.9)
apx13 = compress_pca(image1, pct_var = 0.8)

# %%
apx21 = compress_pca(image2, pct_var = 0.99)
apx22 = compress_pca(image2, pct_var = 0.9)
apx23 = compress_pca(image2, pct_var = 0.8)

# %%
apx31 = compress_pca(image3, pct_var = 0.99)
apx32 = compress_pca(image3, pct_var = 0.9)
apx33 = compress_pca(image3, pct_var = 0.8)

# %%
plt.imshow(apx11 / 255.0)
plt.draw()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(apx12 / 255.0)
plt.draw()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(apx13 / 255.0)
plt.draw()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(apx21 / 255.0)
plt.draw()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(apx22 / 255.0)
plt.draw()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(apx23 / 255.0)
plt.draw()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(apx31 / 255.0)
plt.draw()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(apx32 / 255.0)
plt.draw()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(apx33 / 255.0)
plt.draw()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
imageio.imwrite('apx11.jpg', apx11)
imageio.imwrite('apx12.jpg', apx12)
imageio.imwrite('apx13.jpg', apx13)
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [-50.053043427708076, 291.78826010377225]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [-67.40467283020216, 341.42784439761925]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [-61.38211392978843, 333.61096830000474]. Convert image to uint8 prior to saving to suppress this warning.

# %%
imageio.imwrite('apx21.jpg', apx21)
imageio.imwrite('apx22.jpg', apx22)
imageio.imwrite('apx23.jpg', apx23)
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [-23.864165508632304, 284.7332930439413]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [-62.09040568209145, 301.644439314525]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [-74.92336452132544, 312.1971430967457]. Convert image to uint8 prior to saving to suppress this warning.

# %%
imageio.imwrite('apx31.jpg', apx31)
imageio.imwrite('apx32.jpg', apx32)
imageio.imwrite('apx33.jpg', apx33)
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [-26.941221671310096, 284.8171317876868]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [-44.33311501278469, 304.7279706824505]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [-49.740263373952644, 312.20520206788444]. Convert image to uint8 prior to saving to suppress this warning.
